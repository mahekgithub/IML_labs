# %%
#Bagthariya Mahek r.
#216270307080
#Practical No.2: Write a NumPy program to implement following operation
#to convert a list of numeric values into a one-dimensional NumPy array

import numpy as np
a=np.array([1,2,3,4])
print(a)

# %%
#Bagthariya Mahek r.
#216270307080
#Practical No.2: Write a NumPy program to implement following operation
#to create a 3x3 matrix with values ranging from 2 to 10

import numpy as np
a = np.array([[[9, 9, 9],[8,8,8],[2,3,4]]])
print(a)

# %%
#Bagthariya Mahek r.
#216270307080
#Practical No.2: Write a NumPy program to implement following operation
#to append values at the end of an array

import numpy as np
a = np.array([1,2,3,4,5,6])
b=np.append(a,7)
print(b)

# %%
#Bagthariya Mahek r.
#216270307080
#Practical No.2: Write a NumPy program to implement following operation
#to create another shape from an array without changing its data (3*2 to 2*3)
x= np.array([3,6,6,3,3,6])
print("original x:", x)

y = x.reshape(3,2)
print("new y of shape 3*2:\n",y)

y = x.reshape(2,3)
print("new y of shape 2*3:\n",y)
