# %%
#Name :Bagthariya Mahek R.
#Enrollment no.:216270307080
#Practical No.4: Write a NumPy program to implement following operation
# to add, subtract, multiply, divide arguments element-wise
import numpy as np
x = np.arange(5)
print("x =", x)
print("x + 5 =", x + 5)
print("x - 5 =", x - 5)
print("x * 2 =", x * 2)
print("x / 2 =", x / 2)

# %%
#Name :Bagthariya Mahek R.
#Enrollment no.:216270307080
#Practical No.4: Write a NumPy program to implement following operation
#to round elements of the array to the nearest integer
import numpy as np
np.round([7.3])

# %%
#Name :Bagthariya Mahek R.
#Enrollment no.:216270307080
#Practical No.4: Write a NumPy program to implement following operation
#to calculate mean across dimension, in a 2D numpy array
import numpy as np
a = np.array([[4, 4], [2, 2]])
print("a:\n", a)

print("Mean of a: ", np.mean(a))
print("Mean of a along axis=0: ", np.mean(a, axis=0))
print("Mean of a along axis=1: ", np.mean(a, axis=1))

# %%
#Name :Bagthariya Mahek R.
#Enrollment no.:216270307080
#Practical No.4: Write a NumPy program to implement following operation
#to calculate the difference between neighboring elements, element-wise of a given array
import numpy as np
a = np.array([2,4,7,8,9,5])
np.diff(a)
